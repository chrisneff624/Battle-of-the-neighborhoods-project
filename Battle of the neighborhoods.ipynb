# %% [markdown]
# # Battle of the nieghborhoods

# %% [markdown]
# ## INTRODUCTION/BUSINESS PROBLEM

# %% [markdown]
# Problem: Which city Pittsburgh or philadelphia would be a good place to start a coffee shop downtown?

# %% [markdown]
# I will look at the current venues and list the coffee shops that already exsist for competitor reasons.

# %% [markdown]
# Which city has more attractions to draw customers to the downtown area.

# %% [markdown]
# ### Data I will be using

# %% [markdown]
# I will be using foursquare and looking for data to pull in and refine and use it to compare the too downtown areas

# %% [markdown]
# number of coffee shops within a center of each of the downtown cities

# %% [markdown]
# number and distance of coffee shops in the downtown

# %% [markdown]
# distance from center of the city

# %% [markdown]
# Following data sources will be needed to extract/generate the required information

# %% [markdown]
# centers of candidate areas will be generated algorithmically and approximate addresses of centers of those areas will be obtained using Google Maps API reverse geocoding
# number of coffee shops and their type and location in every neighborhood will be obtained using Foursquare API
# coordinate of Pittsburgh or Philadelphia center will be obtained using Google Maps API geocoding

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0          conda-forge
#     geopy:         2.0.0-pyh9f0ad1d_0 conda-forge
#
#
# ...
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# ...

# %%
CLIENT_ID = 'KCPXGKELOGCTZN0DGRRKPXVLK2C5VMZINO2HB5BO4GLFFMK1' # your Foursquare ID
CLIENT_SECRET = 'LX32BLC532BSJZW1HDAIM5KSAGR2TGAEWN4HQCF3NID1FYLS' # your Foursquare Secret
VERSION = '20200701'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KCPXGKELOGCTZN0DGRRKPXVLK2C5VMZINO2HB5BO4GLFFMK1
# CLIENT_SECRET:LX32BLC532BSJZW1HDAIM5KSAGR2TGAEWN4HQCF3NID1FYLS

# %%
address = '250 Forbes Avenue, Pittsburgh, PA, 15222, United States of America'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.44026183043749 -80.001540486808

# %%
search_query = 'coffee'
radius = 500
print(search_query + ' .... OK!')
# Out:
# coffee .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=KCPXGKELOGCTZN0DGRRKPXVLK2C5VMZINO2HB5BO4GLFFMK1&client_secret=LX32BLC532BSJZW1HDAIM5KSAGR2TGAEWN4HQCF3NID1FYLS&ll=40.44026183043749,-80.001540486808&v=20200701&query=coffee&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5efc91cea50d067df950c74c'},
#  'response': {'venues': [{'id': '4bd19d80046076b017157271',
#     'name': '21st Street Coffee and Tea',
#     'location': {'address': '225 5th Ave',
#      'crossStreet': 'Btw Liberty Ave. & Wood St.',
#      'lat': 40.44111204385811,
#      'lng': -80.00099394922842,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.44111204385811,
#        'lng': -80.00099394922842}],
#      'distance': 105,
#      'postalCode': '15222',
#      'cc': 'US',
#      'city': 'Pittsburgh',
#      'state': 'PA',
#      'country': 'United States',
#      'formattedAddress': ['225 5th Ave (Btw Liberty Ave. & Wood St.)',
#       'Pittsburgh, PA 15222',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 1  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...     1526818
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 3  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 4  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
#
#                delivery.provider.icon.name  \
# 0                                      NaN
# 1  /delivery_provider_grubhub_20180129.png
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2                                       NaN                          NaN
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                name         categories  \
# 0        21st Street Coffee and Tea        Coffee Shop
# 1     Nicholas Coffee & Tea Company        Coffee Shop
# 2                       Coffee Shop        Coffee Shop
# 3           Rock 'n' Joe Coffee Bar        Coffee Shop
# 4                  Fort Pitt Coffee        Coffee Shop
# 5                   Coffee Ala Cart        Coffee Shop
# 6     On19 Coffee Shop at K&L Gates        Coffee Shop
# 7                 Cool Beans Coffee        Coffee Shop
# 8                 Cool Beans Coffee        Coffee Shop
# 9                       Coffee Shop      Deli / Bodega
# 10         Creative Coffee + Supply        Coffee Shop
# 11  Quick Stop Convenience & Coffee  Food & Drink Shop
# 12                  Cart Coffee Ala               Food
# 13           Tuscany Premium Coffee               Food
# 14                   Redhawk Coffee        Coffee Shop
# 15            The rockin coffee pot           Building
# ...

# %%
dataframe_filtered.name
# Out:
# 0          21st Street Coffee and Tea
# 1       Nicholas Coffee & Tea Company
# 2                         Coffee Shop
# 3             Rock 'n' Joe Coffee Bar
# 4                    Fort Pitt Coffee
# 5                     Coffee Ala Cart
# 6       On19 Coffee Shop at K&L Gates
# 7                   Cool Beans Coffee
# 8                   Cool Beans Coffee
# 9                         Coffee Shop
# 10           Creative Coffee + Supply
# 11    Quick Stop Convenience & Coffee
# 12                    Cart Coffee Ala
# 13             Tuscany Premium Coffee
# 14                     Redhawk Coffee
# 15              The rockin coffee pot
# 16           Niko's Coffee Frick Bldg
# 17                          Starbucks
# 18          Kimpton Monaco Coffee Bar
# 19              Lydiah's Coffee House
# 20                          Starbucks
# 21                          Starbucks
# 22                        Crazy Mocha
# 23                         Cool beans
# 24              Gloria Jean's Coffees
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Hilton Garden Inn, Pittsburgh

# add a red circle marker to represent the Hilton Garden Inn, Pittsburgh 
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Hilton Garden Inn, Pittsburgh',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)
# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# explore closest coffe shop to hotel

# %%
venue_id = '4bd19d80046076b017157271' # ID of 21st Street Coffee and tea
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4bd19d80046076b017157271?client_id=KCPXGKELOGCTZN0DGRRKPXVLK2C5VMZINO2HB5BO4GLFFMK1&client_secret=LX32BLC532BSJZW1HDAIM5KSAGR2TGAEWN4HQCF3NID1FYLS&v=20200701'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4bd19d80046076b017157271',
#  'name': '21st Street Coffee and Tea',
#  'contact': {'phone': '4122810121',
#   'formattedPhone': '(412) 281-0121',
#   'twitter': '21streetcoffee'},
#  'location': {'address': '225 5th Ave',
#   'crossStreet': 'Btw Liberty Ave. & Wood St.',
#   'lat': 40.44111204385811,
#   'lng': -80.00099394922842,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.44111204385811,
#     'lng': -80.00099394922842}],
#   'postalCode': '15222',
#   'cc': 'US',
#   'city': 'Pittsburgh',
#   'state': 'PA',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.6

# %%
venue_id = '4c336b3316adc9289395c39c' # ID of crazy mocha
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4c336b3316adc9289395c39c?client_id=KCPXGKELOGCTZN0DGRRKPXVLK2C5VMZINO2HB5BO4GLFFMK1&client_secret=LX32BLC532BSJZW1HDAIM5KSAGR2TGAEWN4HQCF3NID1FYLS&v=20200701'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'parent', 'hierarchy', 'attributes', 'bestPhoto'])
# {'id': '4c336b3316adc9289395c39c',
#  'name': 'Crazy Mocha',
#  'contact': {'phone': '4122811981', 'formattedPhone': '(412) 281-1981'},
#  'location': {'address': '500 Grant St',
#   'lat': 40.44033967364289,
#   'lng': -79.99530880229463,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.44033967364289,
#     'lng': -79.99530880229463}],
#   'postalCode': '15219',
#   'cc': 'US',
#   'city': 'Pittsburgh',
#   'state': 'PA',
#   'country': 'United States',
#   'formattedAddress': ['500 Grant St',
#    'Pittsburgh, PA 15219',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.2

# %%
result['response']['venue']['tips']['count']
# Out:
# 8

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5efc9b79d2bf83199c5b7771'},
#  'response': {'tips': {'count': 8,
#    'items': [{'id': '4d8b7cfdbc848cfab603f22b',
#      'createdAt': 1300987133,
#      'text': "Come for a laugh & ignore the haters. Try a white mocha w/ vanilla soy and you won't be disappointed!",
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/4d8b7cfdbc848cfab603f22b',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 0,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '1152389',
#       'firstName': 'Marcus',
#       'lastName': 'J',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/1152389_5yIwGZPG_HUfcuaM8SYWscr9sNxK0fSicM6JTDlCGmvOhPYKVgn0rZ7KeldnA7ZMD1WFxOmwn.jpg'}}}]}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                                                                                     text  \
# 0  Come for a laugh & ignore the haters. Try a white mocha w/ vanilla soy and you won't be disappointed!
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  0           0              4d8b7cfdbc848cfab603f22b  Marcus
#
#   user.lastName  user.gender  user.id
# 0  J            NaN           1152389

# %%
user_id = '1552389' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/user/{}?client_id={}&client_secret={}&v={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# send GET request
results = requests.get(url).json()
user_data = results['response']['user']

# display features associated with user
user_data.keys()

# %%
print('First Name: ' + user_data['firstName'])
print('Last Name: ' + user_data['lastName'])
print('Home City: ' + user_data['homeCity'])

# %%
user_data['tips']

# %%
# define tips URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
#                                                                                   text  \
# 0  The owner is a sexy lady. Call her pretty and she'll give you complimentary wine.
# 1  The official theme song is Classy Girls by The Lumineers.
# 2  Always have a cocktail!
# 3  They'll make off menu cocktails for you too.  Just tell the waitress what you like!
# 4  Try the artichoke bread. A must!
#
#    agreeCount  disagreeCount                        id
# 0  1           0              52bf92e8498e4be29a3ac648
# 1  1           0              50f8ac7ae4b03d5962873671
# 2  1           0              50ea50e1e4b0d58a5f50ab7e
# 3  4           0              50c41f61e4b032fa829c0151
# 4  2           0              4f1b610ee4b0e6badb98f542

# %%
tip_id = '4f1b610ee4b0e6badb98f542' # tip id

# define URL
url = 'http://api.foursquare.com/v2/tips/{}?client_id={}&client_secret={}&v={}'.format(tip_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# send GET Request and examine results
result = requests.get(url).json()
print(result['response']['tip']['venue']['name'])
print(result['response']['tip']['venue']['location'])
# Out:
# The Finer Things Club
# {'isFuzzed': True, 'lat': 40.714660147121606, 'lng': -73.94186034276925, 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['Leonard St.', 'Brooklyn, NY 11211', 'United States']}

# %%
# 1. grab prefix of photo
# 2. grab suffix of photo
# 3. concatenate them using the image size  
Image(url='https://igx.4sqi.net/img/user/300x300/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg')
# Out:
# <img src="https://igx.4sqi.net/img/user/300x300/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg"/>

# %% [markdown]
# Now lets look at the Philadelphia coffee shops in downtown

# %%
address = '201 S. Christopher Columbus Blvd., Philadelphia, PA, United States of America'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 39.9453634 -75.14136680714961

# %%
search_query = 'coffee'
radius = 500
print(search_query + ' .... OK!')
# Out:
# coffee .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=KCPXGKELOGCTZN0DGRRKPXVLK2C5VMZINO2HB5BO4GLFFMK1&client_secret=LX32BLC532BSJZW1HDAIM5KSAGR2TGAEWN4HQCF3NID1FYLS&ll=39.9453634,-75.14136680714961&v=20200701&query=coffee&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5efca4e411145c373d3b23ce'},
#  'response': {'venues': [{'id': '4c6adfe9599fbe9a1662913f',
#     'name': 'Coffee Shop',
#     'location': {'crossStreet': '3rd and chestnut',
#      'lat': 39.94704785,
#      'lng': -75.14565978333333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 39.94704785,
#        'lng': -75.14565978333333}],
#      'distance': 411,
#      'postalCode': '19106',
#      'cc': 'US',
#      'city': 'Philadelphia',
#      'state': 'PA',
#      'country': 'United States',
#      'formattedAddress': ['Philadelphia, PA 19106', 'United States']},
#     'categories': [],
#     'referralId': 'v-1593615413',
#     'hasPerk': False},
#    {'id': '4be820a9947820a1967cb4db',
#     'name': 'Bodhi Coffee',
#     'location': {'address': '410 S 2nd St',
#      'crossStreet': 'Pine St',
#      'lat': 39.94285617341323,
#      'lng': -75.14545797458909,
#      'labeledLatLngs': [{'label': 'display',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                                                                                                                                                                                                                 categories  \
# 0  []
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}, 'primary': True}]
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}]
# 3  [{'id': '4d4b7105d754a06374d81259', 'name': 'Food', 'pluralName': 'Food', 'shortName': 'Food', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}]
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
       return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                            name         categories          address  cc  \
# 0  Coffee Shop                   None               NaN              US
# 1  Bodhi Coffee                  Café               410 S 2nd St     US
# 2  Customs Coffee House          Coffee Shop        211 Chestnut St  US
# 3  La Tazza D'Art Coffee House   Food               108 Chestnut St  US
# 4  London Coffee House           Building           Front Street     US
# 5  Stumptown Coffee              Coffee Shop        NaN              US
# 6  Xando Coffee and Bar          Coffee Shop        215 Lombard St   US
# 7  Chez Ben Bistro & Coffee Bar  French Restaurant  401 Chestnut St  US
#
#            city        country       crossStreet  distance  \
# 0  Philadelphia  United States  3rd and chestnut  411
# 1  Philadelphia  United States  Pine St           447
# 2  Philadelphia  United States  NaN               441
# 3  Philadelphia  United States  NaN               326
# ...

# %%
dataframe_filtered.name
# Out:
# 0    Coffee Shop
# 1    Bodhi Coffee
# 2    Customs Coffee House
# 3    La Tazza D'Art Coffee House
# 4    London Coffee House
# 5    Stumptown Coffee
# 6    Xando Coffee and Bar
# 7    Chez Ben Bistro & Coffee Bar
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the hilton hotel

# add a red circle marker to represent the hilton hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Hilton Philadelphia at Penns Landing',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)
# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
    # display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4be820a9947820a1967cb4db' # ID of bodhi coffe
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4be820a9947820a1967cb4db?client_id=KCPXGKELOGCTZN0DGRRKPXVLK2C5VMZINO2HB5BO4GLFFMK1&client_secret=LX32BLC532BSJZW1HDAIM5KSAGR2TGAEWN4HQCF3NID1FYLS&v=20200701'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'delivery', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4be820a9947820a1967cb4db',
#  'name': 'Bodhi Coffee',
#  'contact': {'phone': '2672392928',
#   'formattedPhone': '(267) 239-2928',
#   'twitter': 'bodhicoffee'},
#  'location': {'address': '410 S 2nd St',
#   'crossStreet': 'Pine St',
#   'lat': 39.94285617341323,
#   'lng': -75.14545797458909,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 39.94285617341323,
#     'lng': -75.14545797458909}],
#   'postalCode': '19147',
#   'cc': 'US',
#   'city': 'Philadelphia',
#   'state': 'PA',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.6

# %%
result['response']['venue']['tips']['count']
# Out:
# 23

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5efca6497f80693691002cc2'},
#  'response': {'tips': {'count': 23,
#    'items': [{'id': '4e7cbe53b3ad0e8263d8949f',
#      'createdAt': 1316798035,
#      'text': 'At Bodhi Coffee in Society Hill, the café proudly wears salvaged materials, the Stumptown coffees are available in pour-over and drip styles, and the food is fresh, organic and local.',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/4e7cbe53b3ad0e8263d8949f',
#      'lang': 'en',
#      'likes': {'count': 2,
#       'groups': [{'type': 'others',
#         'count': 2,
#         'items': [{'id': '16697800',
#           'firstName': 'Thirsty',
#           'lastName': 'J',
#           'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#            'suffix': '/16697800_0SO6ajOl_2JcveHiPsa8AbCXNznoyev1VQjUJ9LOX-scoJZcs2GYBf0ukRg1WCHsdpChg3TPi.jpg'}},
#          {'id': '48618321',
#           'firstName': 'Find a Coffice',
# ...

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                                                                                       text  \
# 0  At Bodhi Coffee in Society Hill, the café proudly wears salvaged materials, the Stumptown coffees are available in pour-over and drip styles, and the food is fresh, organic and local.
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  3           0              4e7cbe53b3ad0e8263d8949f  Visit Philly
#
#    user.lastName  user.gender  user.id
# 0 NaN            NaN           1666563

# %%
user_id = '1666563' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/user/{}?client_id={}&client_secret={}&v={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# send GET request
results = requests.get(url).json()
user_data = results['response']['user']

# display features associated with user
user_data.keys()

# %%
print('First Name: ' + user_data['firstName'])
print('Last Name: ' + user_data['lastName'])
print('Home City: ' + user_data['homeCity'])

# %%
user_data['tips']

# %%
# define tips URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)
# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
#                                                                                                                                                                                                         text  \
# 0   If you haven't had a chance to try Crime & Punishment's brews yet, keep an eye out for their Pope Francis-related gose "Jesus Wept", a wheat beer brewed with salt and coriander.
# 1   2nd Story Brewing Co. will go way back in time to welcome Pope Francis to Philly. Their beer "Pater Noster" (or "Our Father" in Latin) is usually made by Trappist monks to enjoy on special occasions.
# 2   Brewers incorporate ingredients from Pope Francis' home country of Argentina in "Papal Pleasure", a Belgian amber brewed with South American candi sugar and infused with oak from Malbec wine barrels.
# ...

# %%
tip_id = '55e711f3498e28de2777b6af' # tip id

# define URL
url = 'http://api.foursquare.com/v2/tips/{}?client_id={}&client_secret={}&v={}'.format(tip_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# send GET Request and examine results
result = requests.get(url).json()
print(result['response']['tip']['venue']['name'])
print(result['response']['tip']['venue']['location'])
# Out:
# Dirty Frank's
# {'address': '347 S 13th St', 'crossStreet': 'at Pine St', 'lat': 39.945338232462035, 'lng': -75.16284383919128, 'labeledLatLngs': [{'label': 'display', 'lat': 39.945338232462035, 'lng': -75.16284383919128}], 'postalCode': '19107', 'cc': 'US', 'city': 'Philadelphia', 'state': 'PA', 'country': 'United States', 'formattedAddress': ['347 S 13th St (at Pine St)', 'Philadelphia, PA 19107', 'United States']}

# %%
user_friends = json_normalize(user_data['friends']['groups'][0]['items'])
user_friends

# %%
# 1. grab prefix of photo
# 2. grab suffix of photo
# 3. concatenate them using the image size  
Image(url='https://igx.4sqi.net/img/user/300x300/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg')
# Out:
# <img src="https://igx.4sqi.net/img/user/300x300/484542633_mK2Yum7T_7Tn9fWpndidJsmw2Hof_6T5vJBKCHPLMK5OL-U5ZiJGj51iwBstcpDLYa3Zvhvis.jpg"/>

# %%
venue_id = '4f32979819836c91c7e6d07d' # ID of xando coffe and bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4f32979819836c91c7e6d07d?client_id=KCPXGKELOGCTZN0DGRRKPXVLK2C5VMZINO2HB5BO4GLFFMK1&client_secret=LX32BLC532BSJZW1HDAIM5KSAGR2TGAEWN4HQCF3NID1FYLS&v=20200701'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '4f32979819836c91c7e6d07d',
#  'name': 'Xando Coffee and Bar',
#  'contact': {'phone': '2159254910', 'formattedPhone': '(215) 925-4910'},
#  'location': {'address': '215 Lombard St',
#   'lat': 39.942514,
#   'lng': -75.146135,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 39.942514,
#     'lng': -75.146135}],
#   'postalCode': '19147',
#   'cc': 'US',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'country': 'United States',
#   'formattedAddress': ['215 Lombard St',
#    'Philadelphia, PA 19147',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/xando-coffee-and-bar/4f32979819836c91c7e6d07d',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '4eb57b597ee5024d7f09684c' # ID of 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4eb57b597ee5024d7f09684c?client_id=KCPXGKELOGCTZN0DGRRKPXVLK2C5VMZINO2HB5BO4GLFFMK1&client_secret=LX32BLC532BSJZW1HDAIM5KSAGR2TGAEWN4HQCF3NID1FYLS&v=20200701'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '4eb57b597ee5024d7f09684c',
#  'name': 'Stumptown Coffee',
#  'contact': {},
#  'location': {'lat': 39.942624110643294,
#   'lng': -75.1457791232607,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 39.942624110643294,
#     'lng': -75.1457791232607}],
#   'postalCode': '19147',
#   'cc': 'US',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'country': 'United States',
#   'formattedAddress': ['Philadelphia, PA 19147', 'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/stumptown-coffee/4eb57b597ee5024d7f09684c',
#  'categories': [{'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '4eb9917af5b994cb99b11ccd' # ID of london coffee house
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4eb9917af5b994cb99b11ccd?client_id=KCPXGKELOGCTZN0DGRRKPXVLK2C5VMZINO2HB5BO4GLFFMK1&client_secret=LX32BLC532BSJZW1HDAIM5KSAGR2TGAEWN4HQCF3NID1FYLS&v=20200701'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'dislike', 'ok', 'venueRatingBlacklisted', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto'])
# {'id': '4eb9917af5b994cb99b11ccd',
#  'name': 'London Coffee House',
#  'contact': {},
#  'location': {'address': 'Front Street',
#   'crossStreet': 'Market Street',
#   'lat': 39.94950401362793,
#   'lng': -75.14201088503086,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 39.94950401362793,
#     'lng': -75.14201088503086}],
#   'postalCode': '19106',
#   'cc': 'US',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'country': 'United States',
#   'formattedAddress': ['Front Street (Market Street)',
#    'Philadelphia, PA 19106',
#    'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/london-coffee-house/4eb9917af5b994cb99b11ccd',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '507c17aae4b02bab1b137755' # ID of 

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/507c17aae4b02bab1b137755?client_id=KCPXGKELOGCTZN0DGRRKPXVLK2C5VMZINO2HB5BO4GLFFMK1&client_secret=LX32BLC532BSJZW1HDAIM5KSAGR2TGAEWN4HQCF3NID1FYLS&v=20200701'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'delivery', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '507c17aae4b02bab1b137755',
#  'name': 'Customs Coffee House',
#  'contact': {},
#  'location': {'address': '211 Chestnut St',
#   'lat': 39.94847394561634,
#   'lng': -75.14458164676223,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 39.94847394561634,
#     'lng': -75.14458164676223},
#    {'label': 'entrance', 'lat': 39.948344, 'lng': -75.144722}],
#   'postalCode': '19106',
#   'cc': 'US',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'country': 'United States',
#   'formattedAddress': ['211 Chestnut St',
#    'Philadelphia, PA 19106',
#    'United States']},
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.7

# %%
venue_id = '4c6adfe9599fbe9a1662913f' # ID of london coffee house
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4c6adfe9599fbe9a1662913f?client_id=KCPXGKELOGCTZN0DGRRKPXVLK2C5VMZINO2HB5BO4GLFFMK1&client_secret=LX32BLC532BSJZW1HDAIM5KSAGR2TGAEWN4HQCF3NID1FYLS&v=20200701'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'dislike', 'ok', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '4c6adfe9599fbe9a1662913f',
#  'name': 'Coffee Shop',
#  'contact': {},
#  'location': {'crossStreet': '3rd and chestnut',
#   'lat': 39.94704785,
#   'lng': -75.14565978333333,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 39.94704785,
#     'lng': -75.14565978333333}],
#   'postalCode': '19106',
#   'cc': 'US',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'country': 'United States',
#   'formattedAddress': ['Philadelphia, PA 19106', 'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/coffee-shop/4c6adfe9599fbe9a1662913f',
#  'categories': [],
#  'verified': False,
#  'stats': {'tipCount': 0},
#  'likes': {'count': 0, 'groups': []},
#  'dislike': False,
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# # this concludes my search of the data of the coffee shops downtown in both citys

# %% [markdown]
# My findings were that there were not as many coffee shops in Philadelphia as there were in pittsburgh 7 - 24

# %% [markdown]
# Also there were not as many that people had put ratings in for on foursquare

# %% [markdown]
# The ratings seem to be the same for the shops in Philadelphia as there were in pittsburgh  8.6, 6.6  / 6.6, 6.2, 8

# %% [markdown]
# the tips were helpful in evauating what types of customer service and level of the coffee shops

# %% [markdown]
# the users also had comment that will help decide where to start the coffee shop.

# %% [markdown]
# Before I could make any conclusioning I would need to gather and analyze more data.
